# %% [markdown]
# # Earnings of Female and Male Employees

# %% [markdown]
# ## Problem Statement
# This project...

# %% [markdown]
# ### Data Source
# The dataset used in this project was originally sourced from the Kaggle library; restructured and uploaded to the Project repo.

# %%
import os

# %% [markdown]
# ## Data Pre-processing
# Average hourly earnings of females, males and persons

# %%
#ignore this box if you are using jupyter lab
#create a function that defines the new directory
# def get_path():
#    print('directory')
   #get the current working directory
#    print(os.getcwd())
 #   print('new directory')
    
#get_path()
#change the directory to the new directory containing the dataset
#os.chdir("C:\\Users\\DELL\\Desktop\\Hamoyecapstoneproject")

#get_path()

# %%
#path = os.getcwd()
#os.listdir(path)

# %% [markdown]
# load the data

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Carol-Kelly/Hamoye-Data-Warehouse-ProjectTeam/main/original_earnings%20dataset.csv',
                 delimiter=',', index_col=0)
row, col = df.shape
print(f'There are {row} rows and {col} columns')
# Out:
# There are 14 rows and 28 columns

# %% [markdown]
# Let us get familiar with the Datasets by checking for its characteristics which include the rows, columns, statistical distribution....e.t.c

# %%
df.head()
# Out:
#    year  females  female managers  female professionals  \
# 0  2004  Females            26.14                 29.02
# 1  2005  Females            28.10                 30.00
# 2  2006  Females            28.60                 30.56
# 3  2007  Females            36.43                 31.93
# 4  2008  Females            32.68                 32.93
#
#    female technicians and trades workers  \
# 0                                  17.90
# 1                                  18.86
# 2                                  19.64
# 3                                  20.98
# 4                                  20.30
#
#    female community and personal service workers  \
# 0                                          18.01
# 1                                          18.20
# 2                                          18.84
# 3                                          19.85
# 4                                          20.97
#
#    female clerical and administrative workers  female sales workers  \
# ...

# %% [markdown]
# we have three categories of gender in the dataset above; Females, Males and, persons(not exclusively a man or woman).https://www23.statcan.gc.ca/imdb/p3Var.pl?Function=DEC&Id=410445

# %%
#check for the columns and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 0 to 13
# Data columns (total 28 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   year                                           14 non-null     int64
#  1   females                                        14 non-null     object
#  2   female managers                                14 non-null     float64
#  3   female professionals                           14 non-null     float64
#  4   female technicians and trades workers          14 non-null     float64
#  5   female community and personal service workers  14 non-null     float64
#  6   female clerical and administrative workers     14 non-null     float64
#  7   female sales workers                           14 non-null     float64
#  8   female machinery operators and drivers         14 non-null     float64
# ...

# %%
#check for null values
df.isna().sum()
# Out:
# year                                             0
# females                                          0
# female managers                                  0
# female professionals                             0
# female technicians and trades workers            0
# female community and personal service workers    0
# female clerical and administrative workers       0
# female sales workers                             0
# female machinery operators and drivers           0
# female labourers                                 0
# males                                            0
# male managers                                    0
# male professionals                               0
# male technicians and trades workers              0
# male community and personal service workers      0
# male clerical and administrative workers         0
# male sales workers                               0
# male machinery operators and drivers             0
# ...

# %%
# check for duplicate values
df.duplicated().any()
# Out:
# False

# %% [markdown]
# There are neither missing values nor duplicated values in this dataset

# %%
# conduct some descriptive statistics
df.describe()
# Out:
#             year  female managers  female professionals  \
# count    14.0000        14.000000             14.000000
# mean   2010.5000        35.964286             37.065714
# std       4.1833         6.134298              6.119284
# min    2004.0000        26.140000             29.020000
# 25%    2007.2500        32.835000             32.180000
# 50%    2010.5000        35.730000             36.000000
# 75%    2013.7500        40.905000             42.835000
# max    2017.0000        46.020000             47.040000
#
#        female technicians and trades workers  \
# count                              14.000000
# mean                               22.979286
# std                                 3.488287
# min                                17.900000
# 25%                                20.217500
# 50%                                23.025000
# 75%                                25.697500
# max                                28.300000
#
# ...

# %% [markdown]
# Column reformatting

# %%
df.columns
# Out:
# Index(['year', 'females', 'female managers', 'female professionals',
#        'female technicians and trades workers',
#        'female community and personal service workers',
#        'female clerical and administrative workers', 'female sales workers',
#        'female machinery operators and drivers', 'female labourers', 'males',
#        'male managers', 'male professionals',
#        'male technicians and trades workers',
#        'male community and personal service workers',
#        'male clerical and administrative workers', 'male sales workers',
#        'male machinery operators and drivers', 'male labourers', 'persons',
#        'person managers', 'person professionals',
#        'person technicians and trades workers',
#        'person community and personal service workers',
#        'person clerical and administrative workers', 'person sales workers',
#        'person machinery operators and drivers', 'person labourers'],
#       dtype='object')

# %%
# replace the space between columns with underscores
df.columns = [i.replace(" ", "_") for i in df.columns]
df.columns
# Out:
# Index(['year', 'females', 'female_managers', 'female_professionals',
#        'female_technicians_and_trades_workers',
#        'female_community_and_personal_service_workers',
#        'female_clerical_and_administrative_workers', 'female_sales_workers',
#        'female_machinery_operators_and_drivers', 'female_labourers', 'males',
#        'male_managers', 'male_professionals',
#        'male_technicians_and_trades_workers',
#        'male_community_and_personal_service_workers',
#        'male_clerical_and_administrative_workers', 'male_sales_workers',
#        'male_machinery_operators_and_drivers', 'male_labourers', 'persons',
#        'person_managers', 'person_professionals',
#        'person_technicians_and_trades_workers',
#        'person_community_and_personal_service_workers',
#        'person_clerical_and_administrative_workers', 'person_sales_workers',
#        'person_machinery_operators_and_drivers', 'person_labourers'],
#       dtype='object')

# %% [markdown]
# Types of workers include:
#
# 1. managers
# 2. professionals
# 3. technicians and tradeworkers
# 4. community and personal service workers
# 5. clerical and administrative workers
# 6. sales workers
# 7. machinery operators and drivers
# 8. labourers

# %% [markdown]
# We restructure the data into three separate datasets consisting of the females, males and persons each.

# %%
df = df.rename(columns={'year':'job_title'})
df
# Out:
#     job_title  females  female_managers  female_professionals  \
# 0        2004  Females            26.14                 29.02
# 1        2005  Females            28.10                 30.00
# 2        2006  Females            28.60                 30.56
# 3        2007  Females            36.43                 31.93
# 4        2008  Females            32.68                 32.93
# 5        2009  Females            33.30                 34.72
# 6        2010  Females            34.41                 35.52
# 7        2011  Females            35.22                 36.48
# 8        2012  Females            36.24                 37.72
# 9        2013  Females            37.26                 38.95
# 10       2014  Females            42.63                 44.13
# 11       2015  Females            42.12                 44.75
# 12       2016  Females            44.35                 45.17
# 13       2017  Females            46.02                 47.04
#
# ...

# %%
df.set_index('job_title', inplace=True)
total_df = df.T
total_df = total_df.drop(['females','males','persons'], axis=0)
total_df
# Out:
# job_title                                       2004   2005   2006   2007  \
# female_managers                                26.14   28.1   28.6  36.43
# female_professionals                           29.02   30.0  30.56  31.93
# female_technicians_and_trades_workers           17.9  18.86  19.64  20.98
# female_community_and_personal_service_workers  18.01   18.2  18.84  19.85
# female_clerical_and_administrative_workers     19.98  20.95  21.73  23.27
# female_sales_workers                           14.79  15.39  16.19  16.78
# female_machinery_operators_and_drivers         16.27  21.49  17.37  18.04
# female_labourers                               16.48  16.71  16.32  17.54
# male_managers                                  33.02  33.13  35.16  38.85
# male_professionals                             34.03   34.2  34.34  38.85
# male_technicians_and_trades_workers            22.15  21.87  22.64  23.97
# male_community_and_personal_service_workers    21.18  22.52  22.74  24.56
# ...

# %% [markdown]
# Females Average hourly earning dataset

# %%
#Extract the females features only from the datasets
df_females = total_df[0:8]
df_females
# Out:
# job_title                                       2004   2005   2006   2007  \
# female_managers                                26.14   28.1   28.6  36.43
# female_professionals                           29.02   30.0  30.56  31.93
# female_technicians_and_trades_workers           17.9  18.86  19.64  20.98
# female_community_and_personal_service_workers  18.01   18.2  18.84  19.85
# female_clerical_and_administrative_workers     19.98  20.95  21.73  23.27
# female_sales_workers                           14.79  15.39  16.19  16.78
# female_machinery_operators_and_drivers         16.27  21.49  17.37  18.04
# female_labourers                               16.48  16.71  16.32  17.54
#
# job_title                                       2008   2009   2010   2011  \
# female_managers                                32.68   33.3  34.41  35.22
# female_professionals                           32.93  34.72  35.52  36.48
# female_technicians_and_trades_workers           20.3  20.19  22.86  23.19
# ...

# %% [markdown]
# Males Average hourly earning dataset

# %%
#Extract the male features only from the datasets
df_males = total_df[8:16]
df_males
# Out:
# job_title                                     2004   2005   2006   2007  \
# male_managers                                33.02  33.13  35.16  38.85
# male_professionals                           34.03   34.2  34.34  38.85
# male_technicians_and_trades_workers          22.15  21.87  22.64  23.97
# male_community_and_personal_service_workers  21.18  22.52  22.74  24.56
# male_clerical_and_administrative_workers     23.19  23.94  26.15  28.52
# male_sales_workers                           18.51  19.01  19.99  20.82
# male_machinery_operators_and_drivers         20.92  21.04  21.36  23.06
# male_labourers                               17.21  17.85  18.18  19.68
#
# job_title                                     2008   2009   2010   2011  \
# male_managers                                38.34  41.67  41.28  43.87
# male_professionals                            39.4  40.12  41.49  45.78
# male_technicians_and_trades_workers          24.81  26.62  27.95  29.26
# ...

# %% [markdown]
# Persons Average hourly earning dataset

# %%
#Extract the persons features only from the datasets
df_persons = total_df[16:]
df_persons
# Out:
# job_title                                       2004   2005   2006   2007  \
# person_managers                                 30.6  31.37  32.82  37.95
# person_professionals                           31.22  31.91  32.28  35.01
# person_technicians_and_trades_workers          21.58  21.42  22.18  23.52
# person_community_and_personal_service_workers  19.03   19.6  20.04  21.32
# person_clerical_and_administrative_workers      20.8  21.71  22.82  24.61
# person_sales_workers                           16.13   16.7  17.57  18.28
# person_machinery_operators_and_drivers         20.39  21.09   21.0  22.55
# person_labourers                               16.95  17.44  17.48  18.88
#
# job_title                                       2008   2009   2010   2011  \
# person_managers                                36.24  38.57  38.73  40.62
# person_professionals                           35.84   37.1  38.14  40.65
# person_technicians_and_trades_workers          24.19  25.68  27.23  28.42
# ...

# %% [markdown]
# EDA

# %%
# The Data will be adjusted here just for the analysis 
# The other aspects can make use of the origianl Dataframe 
# Not-Minding the changes made here. :)  

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Female Earnings Per Year')
leg_list=['Managers', 'Professionals','Technicians and Trades Workers','Community and Personal Service Workers','Clerical and Administrative Workers', 'Sales Workers','Machinery Operators and Drivers', 'Labourers']
x=df_females.columns
y0=df_females.iloc[0]
y1=df_females.iloc[1]
y2=df_females.iloc[2]
y3=df_females.iloc[3]
y4=df_females.iloc[4]
y5=df_females.iloc[5]
y6=df_females.iloc[6]
y7=df_females.iloc[7]
plt.plot(x,y0,marker='o')
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='o')
plt.plot(x,y3,marker='o')
plt.plot(x,y4,marker='o')
plt.plot(x,y5,marker='o')
plt.plot(x,y6,marker='o')
plt.plot(x,y7,marker='o')
plt.legend(leg_list)
# plt.savefig('Females Earnings per Year')
plt.show()


plt.figure(figsize=(12,8))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male Earnings Per Year')
leg_list=['Managers', 'Professionals','Technicians and Trades Workers','Community and Personal Service Workers','Clerical and Administrative Workers', 'Sales Workers','Machinery Operators and Drivers', 'Labourers']
x=df_females.columns
y0=df_males.iloc[0]
y1=df_males.iloc[1]
y2=df_males.iloc[2]
y3=df_males.iloc[3]
y4=df_males.iloc[4]
y5=df_males.iloc[5]
y6=df_males.iloc[6]
y7=df_males.iloc[7]
plt.plot(x,y0,marker='o')
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='o')
plt.plot(x,y3,marker='o')
plt.plot(x,y4,marker='o')
plt.plot(x,y5,marker='o')
plt.plot(x,y6,marker='o')
plt.plot(x,y7,marker='o')
plt.legend(leg_list)
# plt.savefig('Males Earnings per Year')
plt.show()


plt.figure(figsize=(12,8))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Persons Earnings Per Year')
leg_list=['Managers', 'Professionals','Technicians and Trades Workers','Community and Personal Service Workers','Clerical and Administrative Workers', 'Sales Workers','Machinery Operators and Drivers', 'Labourers']
x=df_persons.columns
y0=df_persons.iloc[0]
y1=df_persons.iloc[1]
y2=df_persons.iloc[2]
y3=df_persons.iloc[3]
y4=df_persons.iloc[4]
y5=df_persons.iloc[5]
y6=df_persons.iloc[6]
y7=df_persons.iloc[7]
plt.plot(x,y0,marker='o')
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='o')
plt.plot(x,y3,marker='o')
plt.plot(x,y4,marker='o')
plt.plot(x,y5,marker='o')
plt.plot(x,y6,marker='o')
plt.plot(x,y7,marker='o')
plt.legend(leg_list)
# plt.savefig('Persons Earnings per Year')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Managers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[0]
y2=df_males.iloc[0]
plt.plot(x,y1, marker='o')
plt.plot(x,y2, marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Males vs Females Managers')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Professionals Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[1]
y2=df_males.iloc[1]
plt.plot(x,y1, marker='o')
plt.plot(x,y2, marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Males vs Females Professionals')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Technician and Trade Workers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[2]
y2=df_males.iloc[2]
plt.plot(x,y1, marker='o')
plt.plot(x,y2, marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Males vs Females Technician and Trade Workers')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Community and Personal Service Wokers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[3]
y2=df_males.iloc[3]
plt.plot(x,y1, marker='o')
plt.plot(x,y2, marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Males vs Females Community and Personal Service Wokers')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Clerical and Administrative Workers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[4]
y2=df_males.iloc[4]
plt.plot(x,y1, marker='o')
plt.plot(x,y2, marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Male vs Female Clerical and Administrative Workers')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Sales Workers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[5]
y2=df_males.iloc[5]
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Male vs Female Sales Workers')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Machinery Operators and Drivers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[6]
y2=df_males.iloc[6]
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Male vs Female Machinery Operators and Drivers')
plt.show()


plt.figure(figsize=(12,7))
plt.xlabel('Year')
plt.ylabel('Earnings')
plt.title('Male vs Female Labourers Earnings Per Year')
x=total_df.columns
y1=df_females.iloc[7]
y2=df_males.iloc[7]
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='o')
plt.legend(['Females', 'Males'])
# plt.savefig('Male vs Female Labourers')
plt.show()

# %% [markdown]
# Results from the Exploratory Data Analysis:
#
# - Generally, earnings increased regardless of the gender or the type of job over the years.
# - Managers and Professionals earn more than other types of jobs over the years regardless of the gender
# - Males earn more than females over the years regardless of the typr of job except female machinery operators and drivers in 2005 and 2015 when they earned higher than their counterparts.
# - Also in 2016, male and female machinery operators and drivers approximately earned the same.
# - In 2007, female managers had a sharp increase in their earnings
# - In 2014, female technicians and trade workers had a sharp increase in their earnings
# - In 2008, male community and personal service workers had a sharp increase in their earnings
# - In 2005, female machinery operators and drivers had a sharp increase in their earnings followed by an increased in 2014 and 2015

# %%
sns.set_style('darkgrid')
# %matplotlib inline 

df = pd.read_csv("https://raw.githubusercontent.com/Preshynodis/Hamoye-Data-Warehouse-ProjectTeam/main/earning.csv", delimiter=';', nrows=None)

formatted_column_names = ['year',
 'females',
  'female managers',
  'female professionals',
  'female technicians and trades workers',
  'female community and personal service workers',
  'female clerical and administrative workers',
  'female sales workers',
  'female machinery operators and drivers',
  'female labourers',
  'males',
  'male managers',
  'male professionals',
  'male technicians and trades workers',
  'male community and personal service workers',
  'male clerical and administrative workers',
  'male sales workers',
  'male machinery operators and drivers',
  'male labourers',
  'persons',
  'person managers',
  'person professionals',
  'person technicians and trades workers',
  'person community and personal service workers',
  'person clerical and administrative workers',
  'person sales workers',
  'person machinery operators and drivers',
  'person labourers']


df.columns = formatted_column_names

df =df.rename(columns={'year':'Job title'})

df.set_index('Job title', inplace=True)
total_category = df.T


#Extract the male features only from the datasets
df_males = total_category[9:18]
df_males=df_males.drop('males', axis=0)

#Extract the persons features only from the datasets
df_persons = total_category[18:]
df_persons=df_persons.drop('persons', axis=0)


#converting the females dataframe into int 
for i in df_females.columns:
  df_females[i] = df_females[i].apply(int)

#subsetting the dataset again 
df_females_ = df.iloc[:, :9]
df_males_ = df.iloc[:, 9:18]
df_persons_ = df.iloc[:, 18:]
# Out:
# C:\Users\NDUKWE\AppData\Local\Temp\ipykernel_14716\272761658.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_females[i] = df_females[i].apply(int)

# %%
#with the new subsets created, let's make a line plot first to compare a particular job title between the three genders
plt.figure(figsize= (16, 10))
plt.plot(df_females_['female managers'], color = 'red', label = '% Salary for female managers', marker = '+');
plt.plot(df_males_['male managers'], color = 'blue',label = '% Salary for male managers', marker = '*' );
plt.plot(df_persons_['person managers'], color = 'green', label = '% Salary for person managers', marker = '*');
plt.xlabel("Year",size= 12)
plt.ylabel("Percentage of salary",size=12)
plt.title("Comparison of salary of managers among the genders",size=14)
plt.legend()

# %% [markdown]
# - There is an upward trend in the percentage of salaries as the years go by with a sharp decrease from 2007 after which it slowly began to increase. This could be as a result of the global economic crises.
# - From the plot above, we can see that the male managers have always been earning more than both female and persons' genders.
# - There is a peak in 2007 and 2014 respectively, unfortunateky there is isn't enough data to find out why.

# %%
# Since it might take time to plot for each of the job titles,
# we might as well make a new dataset extracting out the genders to form a "Gender" column such that each job title for each column also has a corresponding gender.

df_females_rename = df_females_.rename(columns = {'females' : 'Gender', 'female managers' : 'managers', 'female professionals' : 'professionals',
       'female technicians and trades workers' : 'technicians and trades workers',
       'female community and personal service workers' : 'community and personal service workers',
       'female clerical and administrative workers' : 'clerical and administrative workers', 'female sales workers' : 'sales workers',
       'female machinery operators and drivers' : 'machinery operators and drivers', 'female labourers' : 'labourers'})

df_males_rename = df_males_.rename(columns = {'males' : 'Gender', 'male managers' : 'managers', 'male professionals' : 'professionals',
       'male technicians and trades workers' : 'technicians and trades workers',
       'male community and personal service workers' : 'community and personal service workers',
       'male clerical and administrative workers' : 'clerical and administrative workers', 'male sales workers' : 'sales workers',
       'male machinery operators and drivers' : 'machinery operators and drivers', 'male labourers' : 'labourers'})

df_persons_rename = df_persons_.rename(columns = {'persons' : 'Gender', 'person managers' : 'managers', 'person professionals' : 'professionals',
       'person technicians and trades workers' : 'technicians and trades workers',
       'person community and personal service workers' : 'community and personal service workers',
       'person clerical and administrative workers' : 'clerical and administrative workers', 'person sales workers' : 'sales workers',
       'person machinery operators and drivers' : 'machinery operators and drivers', 'person labourers' : 'labourers'})

df_full = pd.concat([df_females_rename, df_males_rename, df_persons_rename], axis = 0)

# %%
# Univariate plots 

df_full.hist(figsize=(16,10));

# %% [markdown]
# - The plot above shows distribution of the different job titles and distribution of the percentages of their salaries irrespective of gender.
# - The 'managers' and  'professionals' seem to be the categories with higher payment in salaries .
# - Majority of the managers earn within the range of 35-40 .

# %%
sns.countplot(df_full['Gender']);
plt.title("Gender Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# - It is likely to have that gender count is equal. All being 14, which  is originally the initial number of rows before preprocessing.

# %%
# Bivariate and Multi-variate Analysis 

fig1 = sns.FacetGrid(df_full ,hue = 'Gender', aspect = 5)
fig1.map(sns.kdeplot, 'managers', shade = True)
oldest = df_full['managers'].max()
fig1.set(xlim=(0,oldest))
fig1.add_legend()

# %% [markdown]
# From the 'KDE' plot above comparing by gender the salaries of managers, the :
# - The minimum salary for female managers is less than that of male and persons.
# - The mean salary of male managers is ~42 .
# - Only few managers of the 3 genders earn above 50 .
# - We also note that 'Persons' as managers earn quite high.

# %%
pd.DataFrame(df_full.groupby('Gender')['managers'].mean()).plot(kind='bar', color= 'brown',alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [markdown]
# - The plot above gives summary of inferences stated from the KDE plot above.

# %%
#extracting the dataset gender-wise
df_sub_female = df_full[df_full['Gender']=='Females']
df_sub_male = df_full[df_full['Gender']=='Males']
df_sub_persons = df_full[df_full['Gender']=='Persons']

#grouping the 8 job categories by Gender and finding the mean aggregate
df_agg = pd.DataFrame(df_full.groupby('Gender')['Gender', 'managers', 'professionals', 'technicians and trades workers',
       'community and personal service workers',
       'clerical and administrative workers', 'sales workers',
       'machinery operators and drivers', 'labourers'].mean())

df_agg_ =df_agg.reset_index()

df_full.groupby('Gender').mean().plot.bar()
plt.legend(bbox_to_anchor = (1.01, 0.9), loc=2);

# %% [markdown]
# It is clear from above graphs that females are aways paid the least compared to males and persons.

# %%
df_full2 = df_full.reset_index()

cols = ['Job title', 'managers', 'professionals',
       'technicians and trades workers',
       'community and personal service workers',
       'clerical and administrative workers', 'sales workers',
       'machinery operators and drivers', 'labourers']

# multivariate analysis gender-wise of the different job categories 
for col in cols:
    plt.figure(figsize=(10,5))
    sns.barplot(y=df_full2[col], x= 'Gender', data=df_full2, palette = 'icefire',alpha=0.7)
    plt.title(f"Plots showing gender-wise analysis of the {col}")

# %% [markdown]
# Inferences:
# - For all the job categories, their seem to be a gap in the earnings as females were always the lower than those of male and persons.
# - It would be nice to see if their was a year the females of any job category earned more than the male or persons' counterpart
# - After mentioning above 'to compare earnings of professionals by gender' , the analysis of the 'professionals' job category shows that male professionals over the years have always been earning more than females and persons with an average of ~43 .

# %%
for col in cols:
    plt.figure(figsize=(16, 8));
    df_full2.boxplot(column = col, by = 'Gender',  color = 'brown');

# %%
import numpy as np 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)


df = pd.read_csv("https://raw.githubusercontent.com/Preshynodis/Hamoye-Data-Warehouse-ProjectTeam/main/earning.csv", delimiter=';', nrows=None)

df.columns = [i.replace(" ", "_") for i in df.columns]

# Restructure teh data into seperate datasets consisting of females, males and persons each 
df = df.rename(columns={'year':'job_title'})

df.set_index('job_title', inplace=True)
total_df = df.T
total_df = total_df.drop(['females','males','persons'], axis=0)

df_females = total_df[0:8]                           #Extract the females features only from the datasets

df_males = total_df[8:16]                            #Extract the male features only from the datasets

df_persons = total_df[16:]                           #Extract the persons features only from the datasets

total_df = total_df.T.reset_index().rename(columns={"job_title":"year"})

female = total_df[total_df.columns[0:9]]
female.rename(columns={'female_managers':'Managers', 'female_professionals':"Professionals",
       'female_technicians_and_trades_workers':"Technicians and Trade workers",
       'female_community_and_personal_service_workers':"Community and Personal Service workers",
       'female_clerical_and_administrative_workers':"Clerical and Administrative workers", 'female_sales_workers':"Sales workers",
       'female_machinery_operators_and_drivers':"Machinery Operators and Drivers", 'female_labourers':"Labourers"},inplace=True)

#rearranging the female subset
list_df = []                                           #empty list
for year in female["year"]:                            #iterating through the year column of the female subset
    x = female[female["year"] == year].T.reset_index() #transposing and resetting the index
    x["year"] = year                                   #creating a new column containing year values
    x["gender"] = 'Female'                             #creating a new column containing gender values
    x.drop(index=x.index[0],axis=0,inplace=True)       #dropping the first two rows which are the old year and gender columns that were equally transposed
    list_df.append(x)                                  #appending the resulting dataframe to the external list
for df in list_df:                                     #changing the column names for each dataframe in the list
    df.columns = ["Job_title","earnings","year","gender"]
f = pd.concat(list_df)                                 #concatenating the dataframes in the list together
f.reset_index(drop=True,inplace=True)                  #resetting the index

male = total_df.iloc[:,np.r_[0,9:17]]
male.rename(columns={'male_managers':'Managers', 'male_professionals':"Professionals",
       'male_technicians_and_trades_workers':"Technicians and Trade workers",
       'male_community_and_personal_service_workers':"Community and Personal Service workers",
       'male_clerical_and_administrative_workers':"Clerical and Administrative workers", 'male_sales_workers':"Sales workers",
       'male_machinery_operators_and_drivers':"Machinery Operators and Drivers", 'male_labourers':"Labourers"},inplace=True)

#rearranging the male subset
list_df = []                                           #empty list
for year in male["year"]:                              #iterating through the year column of the male subset
    x = male[male["year"] == year].T.reset_index()     #transposing and resetting the index
    x["year"] = year                                   #creating a new column containing year values
    x["gender"] = 'Male'                               #creating a new column containing gender values
    x.drop(index=x.index[0],axis=0,inplace=True)       #dropping the first two rows which are the old year and gender columns that were equally transposed
    list_df.append(x)                                  #appending the resulting dataframe to the external list
for df in list_df:                                     #changing the column names for each dataframe in the list
    df.columns = ["Job_title","earnings","year","gender"]
m = pd.concat(list_df)                                 #concatenating the dataframes in the list together
m.reset_index(drop=True,inplace=True)                  #resetting the index

persons = total_df.iloc[:,np.r_[0,17:25]]
persons.rename(columns={'person_managers':'Managers', 'person_professionals':"Professionals",
       'person_technicians_and_trades_workers':"Technicians and Trade workers",
       'person_community_and_personal_service_workers':"Community and Personal Service workers",
       'person_clerical_and_administrative_workers':"Clerical and Administrative workers", 'person_sales_workers':"Sales workers",
       'person_machinery_operators_and_drivers':"Machinery Operators and Drivers", 'person_labourers':"Labourers"},inplace=True)

#rearranging the persons subset
list_df = []                                             #empty list
for year in persons["year"]:                             #iterating through the year column of the persons subset
    x = persons[persons["year"] == year].T.reset_index() #transposing and resetting the index
    x["year"] = year                                     #creating a new column containing year values
    x["gender"] = 'Persons'                              #creating a new column containing gender values
    x.drop(index=x.index[0],axis=0,inplace=True)         #dropping the first two rows which are the old year and gender columns that were equally transposed
    list_df.append(x)                                    #appending the resulting dataframe to the external list
for df in list_df:                                       #changing the column names for each dataframe in the list
    df.columns = ["Job_title","earnings","year","gender"]
p = pd.concat(list_df)                                   #concatenating the dataframes in the list together
p.reset_index(drop=True,inplace=True)                    #resetting the index


data = pd.concat([f,m,p]).sort_values(by='year').reset_index(drop=True)

#changing the datatype of earnings to float
data["earnings"] = pd.to_numeric(data["earnings"])
# Out:
# C:\Users\NDUKWE\AppData\Local\Temp\ipykernel_14716\237444831.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female.rename(columns={'female_managers':'Managers', 'female_professionals':"Professionals",
# C:\Users\NDUKWE\AppData\Local\Temp\ipykernel_14716\237444831.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male.rename(columns={'male_managers':'Managers', 'male_professionals':"Professionals",
# C:\Users\NDUKWE\AppData\Local\Temp\ipykernel_14716\237444831.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(221)
sns.violinplot(x="gender",y="earnings",data=data)
ax2 = fig.add_subplot(222)
sns.distplot(f["earnings"],bins=np.arange(min(f["earnings"]-4.79),max(f["earnings"]+2.96),5))
plt.title("Females",fontsize=14,fontweight='bold')
ax3 = fig.add_subplot(223)
sns.distplot(m["earnings"],bins=np.arange(min(m["earnings"]-7.21),max(m["earnings"]+2.09),5))
plt.title("Males",fontsize=14,fontweight='bold')
plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# The Diagram above describes how earning is distibuted per gender
#
# For most female jobs, the average hourly earnings is close to 20 while for most male jobs, the average hourly earnings is a bit higher.
#
#
#
# Most female jobs' average hourly earnings fall between 20 and 25, the second highest bin is 15-20 but for males, the highest and second-highest are 20-25 and 25-30 respectively

# %%
sns.violinplot("earnings",data=data)
# Out:
# <AxesSubplot:xlabel='earnings'>

# %% [markdown]
# The Diagram above describes the overall earnig distribution
#
# For most jobs, the average hourly earnings, regardless of gender, is between 20-30.

# %%
#comparing male earnings and female earnings
m["comparison"] = np.where(m["earnings"] > f["earnings"], 'Higher', 'Lower')
m[m["comparison"] == 'Lower'] #checking for jobs where male earnings were lower than female earnings.
# Out:
#                             Job_title earnings  year gender comparison
# 14   malemachineryoperatorsanddrivers    21.04  2005   Male      Lower
# 94   malemachineryoperatorsanddrivers    30.92  2015   Male      Lower
# 102  malemachineryoperatorsanddrivers    29.65  2016   Male      Lower

# %% [markdown]
# There were three cases where male earned lower than females.
#
#
# In 2005, male machinery operators and drivers earned (on an average) lower than their female co-workers.
#
#
# The same occurred in 2015 and 2016.

# %%
#creating a new column that shows the difference between male earnings and female earnings.
m["female_earnings"] = f["earnings"]                            #adding female earnings to male dataframe
m["difference"] = m["earnings"] - m["female_earnings"]          #computing the difference and storing in a new column
m.sort_values("difference")                                     #sorting the dataframe by the difference column in ascending order

pl = m.sort_values("difference",ascending=False)[:10]
sns.barplot(y="Job_title",x="difference",data=pl)
# Out:
# <AxesSubplot:xlabel='difference', ylabel='Job_title'>

# %% [markdown]
# These four jobs community and personal service workers, professionals,
# managers, and technicians and trade workers had the top ten highest difference in male and female earnings.

# %%
pl2 = m[m["year"] == 2017].sort_values("difference")
sns.barplot(x="difference",y="Job_title",data=pl2)
# Out:
# <AxesSubplot:xlabel='difference', ylabel='Job_title'>

# %% [markdown]
# The job with the highest difference in male and female earnings in 2017 was Managers with a difference of over 6.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Preshynodis/Hamoye-Data-Warehouse-ProjectTeam/main/earning.csv", delimiter=';', nrows=None)

df_clean = df.copy()

# Separate the dataset into male_df, female_df and person_df
df_clean.set_index('year', inplace=True)
total_category = df_clean.T

#Extract the male features only from the datasets
df_males = total_category[9:18]

males_df = df_males.T
males_df.reset_index(inplace = True)

males_df.rename(columns ={ 'males':'gender'}, inplace=True)

columns_list = []
for column in males_df.columns:
    if 'male' not in column:
        columns_list.append(column)
    else:
        new = column.replace('male', '')
        columns_list.append(new)
print(columns_list)

males_df.columns = columns_list

#Extract the females features only from the datasets
df_females = total_category[0:9]

females_df = df_females.T
females_df.reset_index(inplace = True)

females_df.columns = columns_list

#Extract the persons features only from the datasets
df_persons = total_category[18:]

persons_df = df_persons.T
persons_df.reset_index(inplace = True)

persons_df.columns = columns_list

# concatenate the dataframes to one
df_clean = pd.concat([males_df, females_df, persons_df], axis =0)

df_clean = df_clean.melt(id_vars=['year', 'gender'], value_vars= [ 'managers', 'professionals','techniciansandtradesworkers', 'communityandpersonalserviceworkers','clericalandadministrativeworkers', 'salesworkers','machineryoperatorsanddrivers', 'labourers'],var_name= 'career_type', value_name='earning_per_hour' )
# Out:
# ['year', 'gender', 'managers', 'professionals', 'techniciansandtradesworkers', 'communityandpersonalserviceworkers', 'clericalandadministrativeworkers', 'salesworkers', 'machineryoperatorsanddrivers', 'labourers']

# %%
total_gender = df_clean.groupby('gender')['earning_per_hour'].mean()
total_gender = total_gender.reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(data = total_gender, x= 'gender', y = 'earning_per_hour')
plt.xlabel('Gender')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of the Various Gender')
# Out:
# Text(0.5, 1.0, 'Average Hourly Earnings of the Various Gender')

# %% [markdown]
# The figure shows the average houly earnings of the 8 career types over 14years period (2004 - 2017) for the various gender.
#
#
# The male gender receives the highest houly wage of AUD30.59 while the female gender receives the least of AUD26.05.

# %%
yearly_gender = df_clean.groupby(['year', 'gender'])['earning_per_hour'].mean()
yearly_gender = yearly_gender.reset_index()
yearly_gender.head()

plt.figure(figsize=(10, 5))
sns.lineplot(data = yearly_gender, x = 'year', y = 'earning_per_hour', hue= 'gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Yearly Average Hourly Earnings of the Various Gender')
# Out:
# Text(0.5, 1.0, 'Yearly Average Hourly Earnings of the Various Gender')

# %% [markdown]
# The graph reveals that there is a constant rising trend of houly wages for the various gender. The difference in hourly wages for the various gender has remain relatively constant over the years.

# %%
career = df_clean.groupby(['career_type', 'gender'])['earning_per_hour'].mean()
career= career.reset_index()

plt.figure(figsize=(10, 8))
sns.barplot(data = career, x = 'earning_per_hour', y = 'career_type', hue = 'gender')
plt.ylabel('Career Type')
plt.xlabel('Earnings per hour')
plt.title('Average Hourly Earnings for Different Career in Australia')
plt.show()

# %% [markdown]
# The Plot shows how hourly wages differ across the various career
#
# It can be observed from the figure that irrespective of career, the male gender has the highest hourly pay while the female has the least. Also the difference between male and the other genders tends to increase for careers with more hourly pay.

# %% [markdown]
# The Plots Below show hourly earnings from 2004 to 2017 based on :
#
# Proffesionals
#
# Managers
#
# Clerical and administrative workers
#
# Technicians and trade workers
#
# Community and personal service workers
#
# Sales workers
#
# Machinery operators and drivers
#
# Labourers, Respectively

# %%
professional = df_clean.query('career_type =="professionals"')

managers = df_clean.query('career_type =="managers"')

clericals = df_clean.query('career_type =="clericalandadministrativeworkers"')

technicians = df_clean.query('career_type =="techniciansandtradesworkers"')

community = df_clean.query('career_type =="communityandpersonalserviceworkers"')

sales = df_clean.query('career_type =="salesworkers"')

machinery = df_clean.query('career_type =="machinery"')

labourers = df_clean.query('career_type =="labourers"')



plt.figure(figsize=(10, 5))
sns.lineplot(data = professional, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Professionals in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data = managers, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Managers in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data = clericals, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Clerial and Administrative Workers in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data = technicians, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Technicians and Trade Workers in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data = community, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Community and Personal Service Workers in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data = sales, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Sales Workers in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data =machinery, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Machinery Opreators and Drivers in Australia')
plt.show()

plt.figure(figsize=(10, 5))
sns.lineplot(data = labourers, x = 'year', y = 'earning_per_hour', hue ='gender')
plt.xlabel('Year')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of Labourers in Australia')
plt.show()
