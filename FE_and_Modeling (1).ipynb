# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Here a slightly different preprocessing is done in order to engineer features and obtain more visualizations

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Carol-Kelly/Hamoye-Data-Warehouse-ProjectTeam/main/original_earnings%20dataset.csv",
                 delimiter=',', index_col=0)
df.head()
# Out:
#    year  females  female managers  female professionals  \
# 0  2004  Females            26.14                 29.02
# 1  2005  Females            28.10                 30.00
# 2  2006  Females            28.60                 30.56
# 3  2007  Females            36.43                 31.93
# 4  2008  Females            32.68                 32.93
#
#    female technicians and trades workers  \
# 0                                  17.90
# 1                                  18.86
# 2                                  19.64
# 3                                  20.98
# 4                                  20.30
#
#    female community and personal service workers  \
# 0                                          18.01
# 1                                          18.20
# 2                                          18.84
# 3                                          19.85
# 4                                          20.97
#
#    female clerical and administrative workers  female sales workers  \
# 0                                       19.98                 14.79
# 1                                       20.95                 15.39
# 2                                       21.73                 16.19
# 3                                       23.27                 16.78
# 4                                       23.67                 17.44
#
#    female machinery operators and drivers  female labourers  ...  \
# 0                                   16.27             16.48  ...
# 1                                   21.49             16.71  ...
# 2                                   17.37             16.32  ...
# 3                                   18.04             17.54  ...
# 4                                   20.27             17.27  ...
#
#   male labourers  persons  person managers  person professionals  \
# 0          17.21  Persons            30.60                 31.22
# 1          17.85  Persons            31.37                 31.91
# 2          18.18  Persons            32.82                 32.28
# 3          19.68  Persons            37.95                 35.01
# 4          19.79  Persons            36.24                 35.84
#
#    person technicians and trades workers  \
# 0                                  21.58
# 1                                  21.42
# 2                                  22.18
# 3                                  23.52
# 4                                  24.19
#
#    person community and personal service workers  \
# 0                                          19.03
# 1                                          19.60
# 2                                          20.04
# 3                                          21.32
# 4                                          24.25
#
#    person clerical and administrative workers  person sales workers  \
# 0                                       20.80                 16.13
# 1                                       21.71                 16.70
# 2                                       22.82                 17.57
# 3                                       24.61                 18.28
# 4                                       24.76                 19.34
#
#    person machinery operators and drivers person labourers
# 0                                   20.39            16.95
# 1                                   21.09            17.44
# 2                                   21.00            17.48
# 3                                   22.55            18.88
# 4                                   23.33            18.85
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (14, 28)

# %%
df_clean = df.copy()

# %%
# Separate the dataset into male_df, female_df and person_df
df_clean.set_index('year', inplace=True)
total_category = df_clean.T
total_category
# Out:
# year                                              2004     2005     2006  \
# females                                        Females  Females  Females
# female managers                                  26.14     28.1     28.6
# female professionals                             29.02     30.0    30.56
# female technicians and trades workers             17.9    18.86    19.64
# female community and personal service workers    18.01     18.2    18.84
# female clerical and administrative workers       19.98    20.95    21.73
# female sales workers                             14.79    15.39    16.19
# female machinery operators and drivers           16.27    21.49    17.37
# female labourers                                 16.48    16.71    16.32
# males                                            Males    Males    Males
# male managers                                    33.02    33.13    35.16
# male professionals                               34.03     34.2    34.34
# male technicians and trades workers              22.15    21.87    22.64
# male community and personal service workers      21.18    22.52    22.74
# male clerical and administrative workers         23.19    23.94    26.15
# male sales workers                               18.51    19.01    19.99
# male machinery operators and drivers             20.92    21.04    21.36
# male labourers                                   17.21    17.85    18.18
# persons                                        Persons  Persons  Persons
# person managers                                   30.6    31.37    32.82
# person professionals                             31.22    31.91    32.28
# person technicians and trades workers            21.58    21.42    22.18
# person community and personal service workers    19.03     19.6    20.04
# person clerical and administrative workers        20.8    21.71    22.82
# person sales workers                             16.13     16.7    17.57
# person machinery operators and drivers           20.39    21.09     21.0
# person labourers                                 16.95    17.44    17.48
#
# year                                              2007     2008     2009  \
# females                                        Females  Females  Females
# female managers                                  36.43    32.68     33.3
# female professionals                             31.93    32.93    34.72
# female technicians and trades workers            20.98     20.3    20.19
# female community and personal service workers    19.85    20.97     21.0
# female clerical and administrative workers       23.27    23.67    23.81
# female sales workers                             16.78    17.44    18.02
# female machinery operators and drivers           18.04    20.27    21.46
# female labourers                                 17.54    17.27     17.9
# males                                            Males    Males    Males
# male managers                                    38.85    38.34    41.67
# male professionals                               38.85     39.4    40.12
# male technicians and trades workers              23.97    24.81    26.62
# male community and personal service workers      24.56    31.35     25.1
# male clerical and administrative workers         28.52    28.04    28.25
# male sales workers                               20.82    22.58     21.6
# male machinery operators and drivers             23.06     23.7    25.44
# male labourers                                   19.68    19.79    19.96
# persons                                        Persons  Persons  Persons
# person managers                                  37.95    36.24    38.57
# person professionals                             35.01    35.84     37.1
# person technicians and trades workers            23.52    24.19    25.68
# person community and personal service workers    21.32    24.25    22.25
# person clerical and administrative workers       24.61    24.76    24.93
# person sales workers                             18.28    19.34    19.38
# person machinery operators and drivers           22.55    23.33    25.05
# person labourers                                 18.88    18.85    19.21
#
# year                                              2010     2011     2012  \
# females                                        Females  Females  Females
# female managers                                  34.41    35.22    36.24
# female professionals                             35.52    36.48    37.72
# female technicians and trades workers            22.86    23.19    23.95
# female community and personal service workers    21.97    23.25    23.52
# female clerical and administrative workers       25.74    26.85    28.35
# female sales workers                             19.15    19.87    20.82
# female machinery operators and drivers           22.74    22.92    24.46
# female labourers                                 19.18    19.82    20.99
# males                                            Males    Males    Males
# male managers                                    41.28    43.87    44.24
# male professionals                               41.49    45.78    45.24
# male technicians and trades workers              27.95    29.26    30.94
# male community and personal service workers      26.99    26.41    29.03
# male clerical and administrative workers         30.69    32.77     32.9
# male sales workers                               23.22    23.99    24.49
# male machinery operators and drivers             27.25    27.16    28.88
# male labourers                                   21.69    22.16    24.18
# persons                                        Persons  Persons  Persons
# person managers                                  38.73    40.62    41.28
# person professionals                             38.14    40.65    41.07
# person technicians and trades workers            27.23    28.42     29.9
# person community and personal service workers     23.5    24.26    25.25
# person clerical and administrative workers       27.04    28.31    29.47
# person sales workers                             20.58    21.41    22.16
# person machinery operators and drivers           26.82    26.74    28.52
# person labourers                                 20.83    21.32    22.99
#
# year                                              2013     2014     2015  \
# females                                        Females  Females  Females
# female managers                                  37.26    42.63    42.12
# female professionals                             38.95    44.13    44.75
# female technicians and trades workers             23.9    27.86     27.5
# female community and personal service workers     24.5    25.01    26.87
# female clerical and administrative workers       28.38    31.52    31.68
# female sales workers                             21.61    22.28    22.99
# female machinery operators and drivers           25.02    29.84    31.91
# female labourers                                 21.75    22.64    23.66
# males                                            Males    Males    Males
# male managers                                    44.85    49.55    49.02
# male professionals                               45.03    50.45    51.05
# male technicians and trades workers              30.82    31.95    33.27
# male community and personal service workers       29.2    31.96    30.74
# male clerical and administrative workers         33.88    35.85    35.72
# male sales workers                               24.55    25.99    26.89
# male machinery operators and drivers             29.83    30.48    30.92
# male labourers                                   24.25    25.22    24.73
# persons                                        Persons  Persons  Persons
# person managers                                  41.99    46.88    46.21
# person professionals                             41.66    46.92    47.53
# person technicians and trades workers            29.81    31.34    32.39
# person community and personal service workers    25.88    27.16    28.11
# person clerical and administrative workers       29.84    32.56    32.69
# person sales workers                             22.67    23.59    24.38
# person machinery operators and drivers           29.36    30.42    31.02
# person labourers                                 23.32    24.29    24.36
#
# year                                              2016     2017
# females                                        Females  Females
# female managers                                  44.35    46.02
# female professionals                             45.17    47.04
# female technicians and trades workers            26.28     28.3
# female community and personal service workers    26.54    27.84
# female clerical and administrative workers       32.35    33.54
# female sales workers                             23.39    26.11
# female machinery operators and drivers           29.73    30.07
# female labourers                                 24.19     24.9
# males                                            Males    Males
# male managers                                    49.77    52.51
# male professionals                               49.49    52.91
# male technicians and trades workers              31.97    34.25
# male community and personal service workers      33.35    32.63
# male clerical and administrative workers         37.77     39.4
# male sales workers                               29.62    29.28
# male machinery operators and drivers             29.65    33.12
# male labourers                                   25.64    27.28
# persons                                        Persons  Persons
# person managers                                  47.66     49.8
# person professionals                             47.03    49.56
# person technicians and trades workers            31.04    33.36
# person community and personal service workers    28.68    29.28
# person clerical and administrative workers       33.76    35.01
# person sales workers                             25.79    27.31
# person machinery operators and drivers           29.66    32.84
# person labourers                                 25.14    26.44

# %%
#Extract the male features only from the datasets
df_males = total_category[9:18]
df_males
# Out:
# year                                          2004   2005   2006   2007  \
# males                                        Males  Males  Males  Males
# male managers                                33.02  33.13  35.16  38.85
# male professionals                           34.03   34.2  34.34  38.85
# male technicians and trades workers          22.15  21.87  22.64  23.97
# male community and personal service workers  21.18  22.52  22.74  24.56
# male clerical and administrative workers     23.19  23.94  26.15  28.52
# male sales workers                           18.51  19.01  19.99  20.82
# male machinery operators and drivers         20.92  21.04  21.36  23.06
# male labourers                               17.21  17.85  18.18  19.68
#
# year                                          2008   2009   2010   2011  \
# males                                        Males  Males  Males  Males
# male managers                                38.34  41.67  41.28  43.87
# male professionals                            39.4  40.12  41.49  45.78
# male technicians and trades workers          24.81  26.62  27.95  29.26
# male community and personal service workers  31.35   25.1  26.99  26.41
# male clerical and administrative workers     28.04  28.25  30.69  32.77
# male sales workers                           22.58   21.6  23.22  23.99
# male machinery operators and drivers          23.7  25.44  27.25  27.16
# male labourers                               19.79  19.96  21.69  22.16
#
# year                                          2012   2013   2014   2015  \
# males                                        Males  Males  Males  Males
# male managers                                44.24  44.85  49.55  49.02
# male professionals                           45.24  45.03  50.45  51.05
# male technicians and trades workers          30.94  30.82  31.95  33.27
# male community and personal service workers  29.03   29.2  31.96  30.74
# male clerical and administrative workers      32.9  33.88  35.85  35.72
# male sales workers                           24.49  24.55  25.99  26.89
# male machinery operators and drivers         28.88  29.83  30.48  30.92
# male labourers                               24.18  24.25  25.22  24.73
#
# year                                          2016   2017
# males                                        Males  Males
# male managers                                49.77  52.51
# male professionals                           49.49  52.91
# male technicians and trades workers          31.97  34.25
# male community and personal service workers  33.35  32.63
# male clerical and administrative workers     37.77   39.4
# male sales workers                           29.62  29.28
# male machinery operators and drivers         29.65  33.12
# male labourers                               25.64  27.28

# %%
males_df = df_males.T
males_df.reset_index(inplace = True)
males_df.head()
# Out:
#    year  males male managers male professionals  \
# 0  2004  Males         33.02              34.03
# 1  2005  Males         33.13               34.2
# 2  2006  Males         35.16              34.34
# 3  2007  Males         38.85              38.85
# 4  2008  Males         38.34               39.4
#
#   male technicians and trades workers  \
# 0                               22.15
# 1                               21.87
# 2                               22.64
# 3                               23.97
# 4                               24.81
#
#   male community and personal service workers  \
# 0                                       21.18
# 1                                       22.52
# 2                                       22.74
# 3                                       24.56
# 4                                       31.35
#
#   male clerical and administrative workers male sales workers  \
# 0                                    23.19              18.51
# 1                                    23.94              19.01
# 2                                    26.15              19.99
# 3                                    28.52              20.82
# 4                                    28.04              22.58
#
#   male machinery operators and drivers male labourers
# 0                                20.92          17.21
# 1                                21.04          17.85
# 2                                21.36          18.18
# 3                                23.06          19.68
# 4                                 23.7          19.79

# %%
males_df.rename(columns ={ 'males':'gender'}, inplace=True)

# %%
columns_list = []
for column in males_df.columns:
    if 'male' not in column:
        columns_list.append(column)
    else:
        new = column.replace('male', '')
        columns_list.append(new)
print(columns_list)
# Out:
# ['year', 'gender', ' managers', ' professionals', ' technicians and trades workers', ' community and personal service workers', ' clerical and administrative workers', ' sales workers', ' machinery operators and drivers', ' labourers']

# %%
males_df.columns = columns_list
males_df.head()
# Out:
#    year gender  managers  professionals  technicians and trades workers  \
# 0  2004  Males     33.02          34.03                           22.15
# 1  2005  Males     33.13           34.2                           21.87
# 2  2006  Males     35.16          34.34                           22.64
# 3  2007  Males     38.85          38.85                           23.97
# 4  2008  Males     38.34           39.4                           24.81
#
#    community and personal service workers  \
# 0                                   21.18
# 1                                   22.52
# 2                                   22.74
# 3                                   24.56
# 4                                   31.35
#
#    clerical and administrative workers  sales workers  \
# 0                                23.19          18.51
# 1                                23.94          19.01
# 2                                26.15          19.99
# 3                                28.52          20.82
# 4                                28.04          22.58
#
#    machinery operators and drivers  labourers
# 0                            20.92      17.21
# 1                            21.04      17.85
# 2                            21.36      18.18
# 3                            23.06      19.68
# 4                             23.7      19.79

# %%
#Extract the females features only from the datasets
df_females = total_category[0:9]
#df_females=df_females.drop('females', axis=0)
df_females
# Out:
# year                                              2004     2005     2006  \
# females                                        Females  Females  Females
# female managers                                  26.14     28.1     28.6
# female professionals                             29.02     30.0    30.56
# female technicians and trades workers             17.9    18.86    19.64
# female community and personal service workers    18.01     18.2    18.84
# female clerical and administrative workers       19.98    20.95    21.73
# female sales workers                             14.79    15.39    16.19
# female machinery operators and drivers           16.27    21.49    17.37
# female labourers                                 16.48    16.71    16.32
#
# year                                              2007     2008     2009  \
# females                                        Females  Females  Females
# female managers                                  36.43    32.68     33.3
# female professionals                             31.93    32.93    34.72
# female technicians and trades workers            20.98     20.3    20.19
# female community and personal service workers    19.85    20.97     21.0
# female clerical and administrative workers       23.27    23.67    23.81
# female sales workers                             16.78    17.44    18.02
# female machinery operators and drivers           18.04    20.27    21.46
# female labourers                                 17.54    17.27     17.9
#
# year                                              2010     2011     2012  \
# females                                        Females  Females  Females
# female managers                                  34.41    35.22    36.24
# female professionals                             35.52    36.48    37.72
# female technicians and trades workers            22.86    23.19    23.95
# female community and personal service workers    21.97    23.25    23.52
# female clerical and administrative workers       25.74    26.85    28.35
# female sales workers                             19.15    19.87    20.82
# female machinery operators and drivers           22.74    22.92    24.46
# female labourers                                 19.18    19.82    20.99
#
# year                                              2013     2014     2015  \
# females                                        Females  Females  Females
# female managers                                  37.26    42.63    42.12
# female professionals                             38.95    44.13    44.75
# female technicians and trades workers             23.9    27.86     27.5
# female community and personal service workers     24.5    25.01    26.87
# female clerical and administrative workers       28.38    31.52    31.68
# female sales workers                             21.61    22.28    22.99
# female machinery operators and drivers           25.02    29.84    31.91
# female labourers                                 21.75    22.64    23.66
#
# year                                              2016     2017
# females                                        Females  Females
# female managers                                  44.35    46.02
# female professionals                             45.17    47.04
# female technicians and trades workers            26.28     28.3
# female community and personal service workers    26.54    27.84
# female clerical and administrative workers       32.35    33.54
# female sales workers                             23.39    26.11
# female machinery operators and drivers           29.73    30.07
# female labourers                                 24.19     24.9

# %%
females_df = df_females.T
females_df.reset_index(inplace = True)
females_df.head()
# Out:
#    year  females female managers female professionals  \
# 0  2004  Females           26.14                29.02
# 1  2005  Females            28.1                 30.0
# 2  2006  Females            28.6                30.56
# 3  2007  Females           36.43                31.93
# 4  2008  Females           32.68                32.93
#
#   female technicians and trades workers  \
# 0                                  17.9
# 1                                 18.86
# 2                                 19.64
# 3                                 20.98
# 4                                  20.3
#
#   female community and personal service workers  \
# 0                                         18.01
# 1                                          18.2
# 2                                         18.84
# 3                                         19.85
# 4                                         20.97
#
#   female clerical and administrative workers female sales workers  \
# 0                                      19.98                14.79
# 1                                      20.95                15.39
# 2                                      21.73                16.19
# 3                                      23.27                16.78
# 4                                      23.67                17.44
#
#   female machinery operators and drivers female labourers
# 0                                  16.27            16.48
# 1                                  21.49            16.71
# 2                                  17.37            16.32
# 3                                  18.04            17.54
# 4                                  20.27            17.27

# %%
females_df.columns = columns_list

# %%
females_df.head()
# Out:
#    year   gender  managers  professionals  technicians and trades workers  \
# 0  2004  Females     26.14          29.02                            17.9
# 1  2005  Females      28.1           30.0                           18.86
# 2  2006  Females      28.6          30.56                           19.64
# 3  2007  Females     36.43          31.93                           20.98
# 4  2008  Females     32.68          32.93                            20.3
#
#    community and personal service workers  \
# 0                                   18.01
# 1                                    18.2
# 2                                   18.84
# 3                                   19.85
# 4                                   20.97
#
#    clerical and administrative workers  sales workers  \
# 0                                19.98          14.79
# 1                                20.95          15.39
# 2                                21.73          16.19
# 3                                23.27          16.78
# 4                                23.67          17.44
#
#    machinery operators and drivers  labourers
# 0                            16.27      16.48
# 1                            21.49      16.71
# 2                            17.37      16.32
# 3                            18.04      17.54
# 4                            20.27      17.27

# %%
#Extract the persons features only from the datasets
df_persons = total_category[18:]
#df_persons=df_persons.drop('persons', axis=0)
df_persons
# Out:
# year                                              2004     2005     2006  \
# persons                                        Persons  Persons  Persons
# person managers                                   30.6    31.37    32.82
# person professionals                             31.22    31.91    32.28
# person technicians and trades workers            21.58    21.42    22.18
# person community and personal service workers    19.03     19.6    20.04
# person clerical and administrative workers        20.8    21.71    22.82
# person sales workers                             16.13     16.7    17.57
# person machinery operators and drivers           20.39    21.09     21.0
# person labourers                                 16.95    17.44    17.48
#
# year                                              2007     2008     2009  \
# persons                                        Persons  Persons  Persons
# person managers                                  37.95    36.24    38.57
# person professionals                             35.01    35.84     37.1
# person technicians and trades workers            23.52    24.19    25.68
# person community and personal service workers    21.32    24.25    22.25
# person clerical and administrative workers       24.61    24.76    24.93
# person sales workers                             18.28    19.34    19.38
# person machinery operators and drivers           22.55    23.33    25.05
# person labourers                                 18.88    18.85    19.21
#
# year                                              2010     2011     2012  \
# persons                                        Persons  Persons  Persons
# person managers                                  38.73    40.62    41.28
# person professionals                             38.14    40.65    41.07
# person technicians and trades workers            27.23    28.42     29.9
# person community and personal service workers     23.5    24.26    25.25
# person clerical and administrative workers       27.04    28.31    29.47
# person sales workers                             20.58    21.41    22.16
# person machinery operators and drivers           26.82    26.74    28.52
# person labourers                                 20.83    21.32    22.99
#
# year                                              2013     2014     2015  \
# persons                                        Persons  Persons  Persons
# person managers                                  41.99    46.88    46.21
# person professionals                             41.66    46.92    47.53
# person technicians and trades workers            29.81    31.34    32.39
# person community and personal service workers    25.88    27.16    28.11
# person clerical and administrative workers       29.84    32.56    32.69
# person sales workers                             22.67    23.59    24.38
# person machinery operators and drivers           29.36    30.42    31.02
# person labourers                                 23.32    24.29    24.36
#
# year                                              2016     2017
# persons                                        Persons  Persons
# person managers                                  47.66     49.8
# person professionals                             47.03    49.56
# person technicians and trades workers            31.04    33.36
# person community and personal service workers    28.68    29.28
# person clerical and administrative workers       33.76    35.01
# person sales workers                             25.79    27.31
# person machinery operators and drivers           29.66    32.84
# person labourers                                 25.14    26.44

# %%
persons_df = df_persons.T
persons_df.reset_index(inplace = True)
persons_df.head()
# Out:
#    year  persons person managers person professionals  \
# 0  2004  Persons            30.6                31.22
# 1  2005  Persons           31.37                31.91
# 2  2006  Persons           32.82                32.28
# 3  2007  Persons           37.95                35.01
# 4  2008  Persons           36.24                35.84
#
#   person technicians and trades workers  \
# 0                                 21.58
# 1                                 21.42
# 2                                 22.18
# 3                                 23.52
# 4                                 24.19
#
#   person community and personal service workers  \
# 0                                         19.03
# 1                                          19.6
# 2                                         20.04
# 3                                         21.32
# 4                                         24.25
#
#   person clerical and administrative workers person sales workers  \
# 0                                       20.8                16.13
# 1                                      21.71                 16.7
# 2                                      22.82                17.57
# 3                                      24.61                18.28
# 4                                      24.76                19.34
#
#   person machinery operators and drivers person labourers
# 0                                  20.39            16.95
# 1                                  21.09            17.44
# 2                                   21.0            17.48
# 3                                  22.55            18.88
# 4                                  23.33            18.85

# %%
persons_df.columns = columns_list
persons_df.head()
# Out:
#    year   gender  managers  professionals  technicians and trades workers  \
# 0  2004  Persons      30.6          31.22                           21.58
# 1  2005  Persons     31.37          31.91                           21.42
# 2  2006  Persons     32.82          32.28                           22.18
# 3  2007  Persons     37.95          35.01                           23.52
# 4  2008  Persons     36.24          35.84                           24.19
#
#    community and personal service workers  \
# 0                                   19.03
# 1                                    19.6
# 2                                   20.04
# 3                                   21.32
# 4                                   24.25
#
#    clerical and administrative workers  sales workers  \
# 0                                 20.8          16.13
# 1                                21.71           16.7
# 2                                22.82          17.57
# 3                                24.61          18.28
# 4                                24.76          19.34
#
#    machinery operators and drivers  labourers
# 0                            20.39      16.95
# 1                            21.09      17.44
# 2                             21.0      17.48
# 3                            22.55      18.88
# 4                            23.33      18.85

# %%
# concatenate the dataframes to one
df_clean = pd.concat([males_df, females_df, persons_df], axis =0)
df_clean.shape
# Out:
# (42, 10)

# %%
df_clean.columns
# Out:
# Index(['year', 'gender', ' managers', ' professionals',
#        ' technicians and trades workers',
#        ' community and personal service workers',
#        ' clerical and administrative workers', ' sales workers',
#        ' machinery operators and drivers', ' labourers'],
#       dtype='object')

# %%
df_clean = df_clean.melt(id_vars=['year', 'gender'], var_name= 'job_type', value_name='earning_per_hour')
                         
df_clean.shape
# Out:
# (336, 4)

# %%
df_clean
# Out:
#      year   gender    job_type earning_per_hour
# 0    2004    Males    managers            33.02
# 1    2005    Males    managers            33.13
# 2    2006    Males    managers            35.16
# 3    2007    Males    managers            38.85
# 4    2008    Males    managers            38.34
# ..    ...      ...         ...              ...
# 331  2013  Persons   labourers            23.32
# 332  2014  Persons   labourers            24.29
# 333  2015  Persons   labourers            24.36
# 334  2016  Persons   labourers            25.14
# 335  2017  Persons   labourers            26.44
#
# [336 rows x 4 columns]

# %%
df_clean.sort_values("year")
# Out:
#      year   gender                              job_type earning_per_hour
# 0    2004    Males                              managers            33.02
# 224  2004  Females                         sales workers            14.79
# 210  2004    Males                         sales workers            18.51
# 28   2004  Persons                              managers             30.6
# 182  2004  Females   clerical and administrative workers            19.98
# ..    ...      ...                                   ...              ...
# 251  2017  Persons                         sales workers            27.31
# 265  2017    Males       machinery operators and drivers            33.12
# 279  2017  Females       machinery operators and drivers            30.07
# 307  2017    Males                             labourers            27.28
# 335  2017  Persons                             labourers            26.44
#
# [336 rows x 4 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              336 non-null    int64
#  1   gender            336 non-null    object
#  2   job_type          336 non-null    object
#  3   earning_per_hour  336 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 10.6+ KB

# %% [markdown]
# #### More Analysis

# %%
total_gender = df_clean.groupby('gender')['earning_per_hour'].mean()
total_gender = total_gender.reset_index()
total_gender.head()
# Out:
#     gender  earning_per_hour
# 0  Females         26.054375
# 1    Males         30.590268
# 2  Persons         28.457143

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data = total_gender, x= 'gender', y = 'earning_per_hour')
plt.xlabel('Gender')
plt.ylabel('Earnings per hour')
plt.title('Average Hourly Earnings of the Various Gender')
# Out:
# Text(0.5, 1.0, 'Average Hourly Earnings of the Various Gender')

# %% [markdown]
# The figure above shows the average houly earning of the eight cadres over the total period of analysis (2004 - 2017) for the various gender. The male gender receives the highest hourly wage of AUD30.59 while the female gender receives the least of AUD26.05.

# %%
plt.figure(figsize=(12, 8))
sns.distplot(df_clean['earning_per_hour'], kde= True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# From the visualization above, it can be seen that overall, irrespective of cadre, most employees in Australia earn an average hourly wage of about AUD25.

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data= df_clean, y = 'earning_per_hour', x= 'gender')

# %%
plt.figure(figsize=(12, 10))
sns.boxplot(data= df_clean, x = 'earning_per_hour', y= 'job_type', hue = 'gender')

# %% [markdown]
# In the first boxplot where the dataset was divided according to gender, there were outliers; but when the plot was further divided taking into account the various cadres occupied by the gender, there are no more outliers. Signifying that all earnings, regardless of job titles are within range.

# %% [markdown]
# ### Feature Engineering
# Creating our target variable, wage-gap.

# %%
df_clean.head()
# Out:
#    year gender   job_type earning_per_hour
# 0  2004  Males   managers            33.02
# 1  2005  Males   managers            33.13
# 2  2006  Males   managers            35.16
# 3  2007  Males   managers            38.85
# 4  2008  Males   managers            38.34

# %%
# Query out male and female data
male_data = df_clean.query('gender == "Males"')
female_data = df_clean.query('gender == "Females"')
print(male_data.shape, female_data.shape)
# Out:
# (112, 4) (112, 4)

# %%
# create an average hourly wage in each year for both male and female
male_data = male_data.groupby('year')['earning_per_hour'].mean()
male_data =male_data.reset_index()
male_data=male_data.rename(columns = {'earning_per_hour':'male_hourly_wage'})
female_data = female_data.groupby('year')['earning_per_hour'].mean()
female_data = female_data.reset_index()
female_data= female_data.rename(columns = {'earning_per_hour':'female_hourly_wage'})

# %%
data = male_data.merge(female_data, on = 'year', how ='outer')
data
# Out:
#     year  male_hourly_wage  female_hourly_wage
# 0   2004          23.77625            19.82375
# 1   2005          24.19500            21.21250
# 2   2006          25.07000            21.15625
# 3   2007          27.28875            23.10250
# 4   2008          28.50125            23.19125
# 5   2009          28.59500            23.80000
# 6   2010          30.07000            25.19625
# 7   2011          31.42500            25.95000
# 8   2012          32.48750            27.00625
# 9   2013          32.80125            27.67125
# 10  2014          35.18125            30.73875
# 11  2015          35.29250            31.43500
# 12  2016          35.90750            31.50000
# 13  2017          37.67250            32.97750

# %%
# create the hourly wage gap between male and female
data['wage_gap'] = data.male_hourly_wage - data.female_hourly_wage
data
# Out:
#     year  male_hourly_wage  female_hourly_wage  wage_gap
# 0   2004          23.77625            19.82375   3.95250
# 1   2005          24.19500            21.21250   2.98250
# 2   2006          25.07000            21.15625   3.91375
# 3   2007          27.28875            23.10250   4.18625
# 4   2008          28.50125            23.19125   5.31000
# 5   2009          28.59500            23.80000   4.79500
# 6   2010          30.07000            25.19625   4.87375
# 7   2011          31.42500            25.95000   5.47500
# 8   2012          32.48750            27.00625   5.48125
# 9   2013          32.80125            27.67125   5.13000
# 10  2014          35.18125            30.73875   4.44250
# 11  2015          35.29250            31.43500   3.85750
# 12  2016          35.90750            31.50000   4.40750
# 13  2017          37.67250            32.97750   4.69500

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data =data, x ='year', y ='wage_gap')

# %%
data.index = pd.to_datetime(data.index)

# %%
# %matplotlib inline 
plt.figure(figsize=(12,8))
data.set_index('year').plot()

# %% [markdown]
# We realize the wage gap has been on a steady trend around 5 dollars in hourly wage. We can easily infer that this data doesn't have seasonality. The wage_gap is independent of time.

# %% [markdown]
# ### Time Series Analysis and Modeling  (The Box - Jenkins Method)

# %% [markdown]
# **Using the ARIMA model**

# %%
data.year = data.year.astype('str')
data.year = data.year + '-01-01 00:00:00'
data.head()
# Out:
#                                               year  male_hourly_wage  \
# 1970-01-01 00:00:00.000000000  2004-01-01 00:00:00          23.77625
# 1970-01-01 00:00:00.000000001  2005-01-01 00:00:00          24.19500
# 1970-01-01 00:00:00.000000002  2006-01-01 00:00:00          25.07000
# 1970-01-01 00:00:00.000000003  2007-01-01 00:00:00          27.28875
# 1970-01-01 00:00:00.000000004  2008-01-01 00:00:00          28.50125
#
#                                female_hourly_wage  wage_gap
# 1970-01-01 00:00:00.000000000            19.82375   3.95250
# 1970-01-01 00:00:00.000000001            21.21250   2.98250
# 1970-01-01 00:00:00.000000002            21.15625   3.91375
# 1970-01-01 00:00:00.000000003            23.10250   4.18625
# 1970-01-01 00:00:00.000000004            23.19125   5.31000

# %%
data.year = pd.to_datetime(data.year)
data.set_index( "year" , inplace= True)
data.head()
# Out:
#             male_hourly_wage  female_hourly_wage  wage_gap
# year
# 2004-01-01          23.77625            19.82375   3.95250
# 2005-01-01          24.19500            21.21250   2.98250
# 2006-01-01          25.07000            21.15625   3.91375
# 2007-01-01          27.28875            23.10250   4.18625
# 2008-01-01          28.50125            23.19125   5.31000

# %%
import statsmodels.api as sm
from pylab import rcParams

rcParams[ 'figure.figsize' ] = 15 , 10
decompose_series = sm.tsa.seasonal_decompose(data['wage_gap'], model= 'additive' )
decompose_series.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(data.wage_gap)
print(f'ADF Statistic: {adf_result[ 0 ]} ' )
print(f'p-value: {adf_result[ 1 ]} ' )
print(f'No. of lags used: {adf_result[ 2 ]} ' )
print(f'No. of observations used : {adf_result[ 3 ]} ' )
print('Critical Values:' )
for k, v in adf_result[ 4 ].items():
 print( f' {k} : {v} ' )
# Out:
# ADF Statistic: -2.64823550747674
# p-value: 0.08343201883490259
# No. of lags used: 5
# No. of observations used : 8
# Critical Values:
#  1% : -4.6651863281249994
#  5% : -3.3671868750000002
#  10% : -2.802960625

# %% [markdown]
# The result shows that the p-value is greater than the critical value (0.05) and the ADF statistic is also greater than the critical value at 5%. Therefore, the series is non-stationary.

# %%
# conducting the first differencing 
data['wage_gap_diff'] = data['wage_gap'] - data['wage_gap'].shift(1)

# %%
# test again to ensure stationarity
def adfTest(series):
    result=adfuller(series)
    print('ADF statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    if (result[1] <= 0.05):
        print('We reject the null hypothesis (H0), this data is Stationary')
    else:
        print('We accept the null hypothesis (H0) because the dataset is Non-Stationary')
          
adfTest(data['wage_gap_diff'].dropna())
# Out:
# ADF statistic: -3.9551363114829474
# p-value: 0.0016645350483805406
# We reject the null hypothesis (H0), this data is Stationary

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import warnings
warnings.filterwarnings("ignore")

#ACF
plot_acf(data['wage_gap_diff'].dropna(), lags=range(0 , 6))
plt.show()
#PACF
plot_pacf(data['wage_gap_diff'].dropna(), lags=range(0 , 6))
plt.show()

# %% [markdown]
# In both the ACF and PACF plots, no lag crossed the significant level; hence, q=p=0. Therefore, the ARIMA order is (0,0,0)

# %%
# divide the data into train and test sets
test_size = (len(data) - 4)

train_data = data[:test_size]
test_data = data[test_size:]

# %%
train_data
# Out:
#             male_hourly_wage  female_hourly_wage  wage_gap  wage_gap_diff
# year
# 2004-01-01          23.77625            19.82375   3.95250            NaN
# 2005-01-01          24.19500            21.21250   2.98250       -0.97000
# 2006-01-01          25.07000            21.15625   3.91375        0.93125
# 2007-01-01          27.28875            23.10250   4.18625        0.27250
# 2008-01-01          28.50125            23.19125   5.31000        1.12375
# 2009-01-01          28.59500            23.80000   4.79500       -0.51500
# 2010-01-01          30.07000            25.19625   4.87375        0.07875
# 2011-01-01          31.42500            25.95000   5.47500        0.60125
# 2012-01-01          32.48750            27.00625   5.48125        0.00625
# 2013-01-01          32.80125            27.67125   5.13000       -0.35125

# %%
test_data
# Out:
#             male_hourly_wage  female_hourly_wage  wage_gap  wage_gap_diff
# year
# 2014-01-01          35.18125            30.73875    4.4425        -0.6875
# 2015-01-01          35.29250            31.43500    3.8575        -0.5850
# 2016-01-01          35.90750            31.50000    4.4075         0.5500
# 2017-01-01          37.67250            32.97750    4.6950         0.2875

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train_data['wage_gap'], order=(0,0,0))
fit_model = model.fit()

# %%
fit_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               wage_gap   No. Observations:                   10
# Model:                          ARIMA   Log Likelihood                 -11.732
# Date:                Sun, 23 Oct 2022   AIC                             27.463
# Time:                        04:15:48   BIC                             28.069
# Sample:                    01-01-2004   HQIC                            26.800
#                          - 01-01-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6100      0.300     15.356      0.000       4.022       5.198
# sigma2         0.6117      0.399      1.533      0.125      -0.170       1.394
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.19   Jarque-Bera (JB):                 0.90
# Prob(Q):                              0.02   Prob(JB):                         0.64
# Heteroskedasticity (H):               0.50   Skew:                            -0.67
# Prob(H) (two-sided):                  0.58   Kurtosis:                         2.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# make predictions
start_pred = test_data.index[0]
end_pred = test_data.index[-1]
pred = fit_model.predict(start=start_pred, end=end_pred)
pred
# Out:
# 2014-01-01    4.609995
# 2015-01-01    4.609995
# 2016-01-01    4.609995
# 2017-01-01    4.609995
# Freq: AS-JAN, Name: predicted_mean, dtype: float64

# %%
# plot residual
fit_model.resid.plot(kind='kde', figsize=(7,4))

# %%
# Visualize the forecasts (blue=train, green=forecasts)
x = np.arange(data.shape[0])
plt.figure(figsize=(10,8))
plt.plot(x[:-4], train_data, c='blue')
plt.plot(x[-4:], pred, c='green')
plt.show()

# %% [markdown]
# **Model Evaluation (ARIMA)**

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

mse1 = mean_squared_error(y_pred=pred, y_true=test_data['wage_gap'])
mape1 = mean_absolute_percentage_error(y_pred=pred, y_true=test_data['wage_gap'])
print('MSE of ARIMA: {}\nMAPE of ARIMA: {}'.format(mse1, mape1))
# Out:
# MSE of ARIMA: 0.16063336470646364
# MAPE of ARIMA: 0.07420620847041526

# %% [markdown]
# **Using the Prophet model**

# %%
from prophet import Prophet

# %%
# remame the df in an acceptable format
data2 = data.copy().reset_index()
data2 = data2[['year','wage_gap']]
data2.columns = ['ds', 'y']
data2.head()
# Out:
#           ds        y
# 0 2004-01-01  3.95250
# 1 2005-01-01  2.98250
# 2 2006-01-01  3.91375
# 3 2007-01-01  4.18625
# 4 2008-01-01  5.31000

# %%
data2.plot(x='ds',y='y',figsize=(18,6))

# %%
# split to train and test set
print(data2.shape)
train=data2.iloc[:-4]
test=data2.iloc[-4:]
print(train.shape,test.shape)
# Out:
# (14, 2)
# (10, 2) (4, 2)

# %%
model2 = Prophet()
model2.fit(train)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 7.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpim99lxrb/4k7f6rk5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpim99lxrb/d4srxvrb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18595', 'data', 'file=/tmp/tmpim99lxrb/4k7f6rk5.json', 'init=/tmp/tmpim99lxrb/d4srxvrb.json', 'output', 'file=/tmp/tmpim99lxrb/prophet_modelmrmt_3id/prophet_model-20221023041551.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 04:15:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 04:15:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
train
# Out:
#           ds        y
# 0 2004-01-01  3.95250
# 1 2005-01-01  2.98250
# 2 2006-01-01  3.91375
# 3 2007-01-01  4.18625
# 4 2008-01-01  5.31000
# 5 2009-01-01  4.79500
# 6 2010-01-01  4.87375
# 7 2011-01-01  5.47500
# 8 2012-01-01  5.48125
# 9 2013-01-01  5.13000

# %%
test
# Out:
#            ds       y
# 10 2014-01-01  4.4425
# 11 2015-01-01  3.8575
# 12 2016-01-01  4.4075
# 13 2017-01-01  4.6950

# %%
forecast2 = model2.predict(test.drop(columns='y'))

# %%
forecast2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#           ds      yhat  yhat_lower  yhat_upper
# 0 2014-01-01  5.785619    5.452596    6.133870
# 1 2015-01-01  6.301862    5.931138    6.649768
# 2 2016-01-01  6.815162    6.455821    7.175187
# 3 2017-01-01  6.221417    5.874003    6.578887

# %%
# Calculate MSE and MAPE 
mse2 = mean_squared_error(forecast2['yhat'], test.y)
mape2 = mean_absolute_percentage_error(forecast2['yhat'], test.y)
print(f'The MSE value for prophet: {mse2}')
print(f'The MAPE value for prophet: {mape2}')
# Out:
# The MSE value for prophet: 3.9764131214798004
# The MSE value for prophet: 0.3046639951418161

# %%
comparison_table = pd.DataFrame({'Models':['ARIMA', 'Prophet'], 'MSE':[mse1, mse2], 'MAPE':[mape1, mape2]})
comparison_table
# Out:
#     Models       MSE      MAPE
# 0    ARIMA  0.160633  0.074206
# 1  Prophet  3.976413  0.304664

# %% [markdown]
# ARIMA seems to be the better model with lower score of MSE and MAPE

# %%
# plot forecast for the test data (prophet model)
model2.plot(forecast2)
model2.plot_components(forecast2)
plt.show()

# %% [markdown]
# **Model Evaluation (Prophet)**

# %%
# pickle the better model
import pickle
pickle.dump(fit_model, open('model.pkl', 'wb'))
